# %% [markdown]
# ### Step 1. Define and compile NN model

# %%
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.layers import Dense,Input
from tensorflow.keras import regularizers
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import Lambda
from tensorflow.keras import Model
import tensorflow as tf

def build_model(num_tf,num_feature_type):
    inputs = [Input(shape = (num_feature_type,)) for i in range(num_tf)]
    concat_layer = [Dense(1, activation = "relu", kernel_regularizer = tf.keras.regularizers.l1(0.01))(inp) for inp in inputs]
    concat_layer = concatenate(concat_layer)
    out = Dense(64, activation = "relu", kernel_regularizer = tf.keras.regularizers.l1(0.01))(concat_layer)
    out = Dense(32, activation = "relu", kernel_regularizer = tf.keras.regularizers.l1(0.01))(out)
    out = Dense(16, activation = "relu", kernel_regularizer = tf.keras.regularizers.l1(0.01))(out)
    out = Dense(1, activation = "linear")(out)
    model = Model(inputs = inputs, outputs = out)
    model.compile(loss = 'mean_squared_error',
                  metrics = 'mean_absolute_error',
                  optimizer = "SGD")
    return(model)
# Out:
# 2021-12-12 21:04:15.417435: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# ### Step 2. Load expression, TF activitiy scores, and ensembl ID mapping file

# %% [markdown]
# First, read RPKM values and velocity values and then scale them

# %%
import h5py
import numpy as np
import pandas as pd

rpkm = dict()
with h5py.File('data/processed/rpkm/rpkm.hdf5', 'r') as f:
    for tissue in f.keys():
        
        # scale the rpkm by log10
        rpkm[tissue] = pd.DataFrame(np.log10(np.array(f[tissue]['exp'])+1),
                                        index = np.array(f[tissue]['barcode']).astype(str),
                                        columns = np.array(f[tissue]['ensembl']).astype(str))

velo = dict()
with h5py.File('data/processed/velo/velo.hdf5', 'r') as f:
    for tissue in f.keys():
        velo[tissue] = pd.DataFrame(np.array(f[tissue]['velo']),
                                        index = np.array(f[tissue]['barcode']).astype(str),
                                        columns = np.array(f[tissue]['ensembl']).astype(str))

# %% [markdown]
# Read TF activity score matrices. Missing values are treated as zeros.

# %%
import os
import pandas as pd

folder = "data/processed/tf_activity/"

tf_gene_mat_mean = dict()
for filename in os.listdir(folder + "mean_tf/"):
    tissue = "_".join(filename.split("_")[:-1])
    tf_gene_mat_mean[tissue] = pd.read_csv("{}/mean_tf/{}".format(folder,filename),index_col = 0).transpose()
    tf_gene_mat_mean[tissue].fillna(0,inplace = True)

tf_gene_mat_sum = dict()
for filename in os.listdir(folder + "sum_tf/"):
    tissue = "_".join(filename.split("_")[:-1])
    tf_gene_mat_sum[tissue] = pd.read_csv("{}/sum_tf/{}".format(folder,filename),index_col = 0).transpose()
    tf_gene_mat_sum[tissue].fillna(0,inplace = True)
    
    # scale the value by log2
    tf_gene_mat_sum[tissue] = np.log2(tf_gene_mat_sum[tissue]+1)

# %% [markdown]
# Load ensembl to hgnc mapping file

# %%
ensembl_to_symbol = pd.read_csv("data/raw/id_mapping/ensembl_to_symbol.csv",index_col = 0)
ensembl_to_symbol = ensembl_to_symbol.loc[~ensembl_to_symbol["ensembl_id"].duplicated(),:]
ensembl_to_symbol.index = ensembl_to_symbol["ensembl_id"]

# %% [markdown]
# ### Step 3. Select genes for testing
# For each tissue, train and test the model with reps.

# %% [markdown]
# Select 500 genes in each tissue for testing

# %%
import pandas as pd
import re

l1_res = pd.read_csv("results/r2/lasso_r2.csv", index_col=0)

num_genes = 500
num_samples = 4000

# Remove parenthesis and spaces in the tissue name
l1_res["tissue"] = l1_res['tissue'].str.replace('\s+',"_")
l1_res["tissue"] = l1_res['tissue'].str.replace('\(',"")
l1_res["tissue"] = l1_res['tissue'].str.replace('\)',"")

selected_genes = dict()

for tissue,df in l1_res.groupby("tissue"):
        
    # Select genes that have > 4000 cells for velocity values
    sample_counts = (~velo[tissue].isna()).sum(axis = 0)
    genes = sample_counts.index[sample_counts > num_samples].values
    df = df.loc[df["gene_ensembl"].isin(genes),]

    # Randomly select 500 genes in each tissue
    np.random.seed(1000)
    if num_genes < df.shape[0]:
        idx = np.random.choice(np.arange(df.shape[0]), size=num_genes, replace=False)
    else:
        idx = np.arange(df.shape[0])
    selected_genes[tissue] = df.iloc[idx,]["gene_ensembl"].values
    print("{} has {} selected genes.".format(tissue, str(selected_genes[tissue].shape[0])))
# Out:
# /tmp/ipykernel_71661/327824710.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   l1_res["tissue"] = l1_res['tissue'].str.replace('\s+',"_")
# /tmp/ipykernel_71661/327824710.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   l1_res["tissue"] = l1_res['tissue'].str.replace('\(',"")
# /tmp/ipykernel_71661/327824710.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   l1_res["tissue"] = l1_res['tissue'].str.replace('\)',"")
# Heart has 500 selected genes.
# Kidney_Left has 500 selected genes.
# Large_Intestine has 500 selected genes.
# Liver has 500 selected genes.
# Lung_Right has 500 selected genes.
# Spleen has 500 selected genes.

# %%
rpkm_tf = dict()

# Keep TFs as columns for rpkm_tf mat.
tf_list = pd.read_csv("data/raw/tf/tf_list.csv", index_col = 0)
for tissue in velo.keys():
    
    use_tfs = rpkm[tissue].columns.intersection(tf_list["Ensembl ID"])
    rpkm_tf[tissue] = rpkm[tissue].loc[:,use_tfs]

# %% [markdown]
# ### Step 4. Reformat the data matrices to keep the consistent TFs and genes.
# Make rpkm matrix and tf activity matrix have the same tfs
# Make velo matrix and tf activity matrix have the same genes

# %%
act_mat_sum = dict()
act_mat_mean = dict()

for tissue in tf_gene_mat_mean.keys():
    
    # Find common TF 
    tfmat_cols = pd.DataFrame(tf_gene_mat_mean[tissue].columns.values,columns = ['tfmat_cols'])
    comm_tfs = ensembl_to_symbol.merge(how = 'left',
                                        left_on = 'gene_symbol',
                                        right_on = "tfmat_cols",
                                        right = tfmat_cols)
    comm_tfs = comm_tfs.loc[~comm_tfs['tfmat_cols'].isna(),]
    comm_tfs = comm_tfs.loc[comm_tfs["ensembl_id"].isin(rpkm_tf[tissue].columns),]
    
    # Find common (velocity) genes
    tfmat_rows = pd.DataFrame(tf_gene_mat_mean[tissue].index.values,columns = ['tfmat_rows'])
    comm_genes = ensembl_to_symbol.merge(how = 'left',
                                            left_on = 'gene_symbol',
                                            right_on = "tfmat_rows",
                                            right = tfmat_rows)
    comm_genes = comm_genes.loc[~comm_genes['tfmat_rows'].isna(),]
    comm_genes = comm_genes.loc[comm_genes["ensembl_id"].isin(velo[tissue].columns),]
    
    '''
    Reorder rpkm mat, velo mat, and cluster label vectors. The TF-Gene matrix follow the same tf_order and gene_order. In this order, the columns in upper left
    corner are the tfs commonly found in rpkm matrix and tf activity matrix and the rows represent the genes commonly found in velo matrix
    and tf activity matrix.
              TF
           _______ __
          | common|  |
    Genes |_______|  |
          |__________|
    '''
    tf_order = pd.concat([comm_tfs['ensembl_id'], pd.Series(np.setdiff1d(rpkm_tf[tissue].columns, comm_tfs['ensembl_id']))])
    gene_order = pd.concat([comm_genes['ensembl_id'], pd.Series(np.setdiff1d(velo[tissue].columns, comm_genes['ensembl_id']))])
    
    rpkm_tf[tissue] = rpkm_tf[tissue].loc[:,tf_order]
    velo[tissue] = velo[tissue].loc[:,gene_order]
    #cluster_labels[tissue] = cluster_labels[tissue].loc[gene_order,:]
    
    act_mat_sum[tissue] = np.zeros((velo[tissue].shape[1], rpkm_tf[tissue].shape[1]))
    act_mat_mean[tissue] = np.zeros((velo[tissue].shape[1], rpkm_tf[tissue].shape[1]))
    
    act_mat_sum[tissue][:comm_genes.shape[0],:][:,:comm_tfs.shape[0]] = tf_gene_mat_sum[tissue].loc[comm_genes['tfmat_rows'],comm_tfs['tfmat_cols']]
    act_mat_mean[tissue][:comm_genes.shape[0],:][:,:comm_tfs.shape[0]] = tf_gene_mat_mean[tissue].loc[comm_genes['tfmat_rows'],comm_tfs['tfmat_cols']]
    
    act_mat_sum[tissue] = pd.DataFrame(act_mat_sum[tissue], index = gene_order, columns = tf_order)
    act_mat_mean[tissue] = pd.DataFrame(act_mat_mean[tissue], index = gene_order, columns = tf_order)

del tf_gene_mat_mean
del tf_gene_mat_sum

# %% [markdown]
# ### Step 5. Train and test baseline NN models
# This step may take a long time to complte

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from collections import defaultdict
from tensorflow import keras
from joblib import Parallel,delayed
import numpy as np
import tensorflow as tf
import pdb

n_rep = 3
n_epoch = 15
n_jobs = 15
batch_size = 256
test_ratio = 0.1
r2_all = dict()

def train_test_gene(tissue, gene):
    
    r2 = np.zeros((n_rep,))
    for rep in range(n_rep):

        # Reformat data to multiple inputs
        y_train = rpkm[tissue][gene].values[train_idx[rep]]
        y_test = rpkm[tissue][gene].values[test_idx[rep]]

        # Standardize y
        y_train = (y_train - np.mean(y_train))/np.std(y_train)
        y_test = (y_test - np.mean(y_test))/np.std(y_test)

        X_all_train = []
        X_all_test = []

        for TF in rpkm_tf[tissue].columns:

            # To avaoid self-prediction, let TF not equal to the current gene.
            if TF != gene:

                X_all_train.append(np.empty((train_idx[rep].shape[0], 5)))
                X_all_test.append(np.empty((test_idx[rep].shape[0], 5)))

                # Expression rpkms
                X_all_train[-1][:,0] = rpkm_tf[tissue][TF].values[train_idx[rep],]
                X_all_test[-1][:,0] = rpkm_tf[tissue][TF].values[test_idx[rep],]

                # TF mean signals
                X_all_train[-1][:,1] = act_mat_mean[tissue].loc[gene, TF]
                X_all_test[-1][:,1] = act_mat_mean[tissue].loc[gene, TF]

                # TF sum signals
                X_all_train[-1][:,2] = act_mat_sum[tissue].loc[gene, TF]
                X_all_test[-1][:,2] = act_mat_sum[tissue].loc[gene, TF]

                # The product of expressions and TF mean signals
                X_all_train[-1][:,3] =  X_all_train[-1][:,0] * X_all_train[-1][:,1]
                X_all_test[-1][:,3] = X_all_test[-1][:,0] * X_all_test[-1][:,1]

                # The product of expressions and TF sum signals
                X_all_train[-1][:,4] = X_all_train[-1][:,0] * X_all_train[-1][:,2]
                X_all_test[-1][:,4] = X_all_test[-1][:,0] * X_all_test[-1][:,2]

                # Standardize the rpkms and the prod features
                if np.sum(X_all_train[-1][:,0]) != 0:
                    X_all_train[-1][:,0] = (X_all_train[-1][:,0] - np.mean(X_all_train[-1][:,0]))/np.std(X_all_train[-1][:,0])

                if np.sum(X_all_train[-1][:,3]) != 0:
                    X_all_train[-1][:,3] = (X_all_train[-1][:,3] - np.mean(X_all_train[-1][:,3]))/np.std(X_all_train[-1][:,3])

                if np.sum(X_all_train[-1][:,4]) != 0:
                    X_all_train[-1][:,4] = (X_all_train[-1][:,4] - np.mean(X_all_train[-1][:,4]))/np.std(X_all_train[-1][:,4])

                if np.sum(X_all_test[-1][:,0]) != 0:
                    X_all_test[-1][:,0] = (X_all_test[-1][:,0] - np.mean(X_all_test[-1][:,0]))/np.std(X_all_test[-1][:,0])

                if np.sum(X_all_test[-1][:,3]) != 0:
                    X_all_test[-1][:,3] = (X_all_test[-1][:,3] - np.mean(X_all_test[-1][:,3]))/np.std(X_all_test[-1][:,3])

                if np.sum(X_all_test[-1][:,4]) != 0:
                    X_all_test[-1][:,4] = (X_all_test[-1][:,4] - np.mean(X_all_test[-1][:,4]))/np.std(X_all_test[-1][:,4])

        # Compile model
        model = build_model(num_tf = len(X_all_train), num_feature_type = 5)

        # Train model
        model.fit(
            x = X_all_train,
            y = y_train,
            batch_size = batch_size,
            epochs = n_epoch,
            verbose = 0
        )

        # Test model
        y_pred = model.predict(x = X_all_test)
        r2[rep] = r2_score(y_test, y_pred)

    # Save output to file
    with open("results/r2/basenn_expTFAPredExp_r2.csv","a") as f:
        f.writelines("{}, {}, {}, {}\n".format(tissue,gene,str(np.mean(r2)),str(rep)))
        
    return(r2)

for tissue in comm_tissues[-1:]:
    
    # Generate train and test sample indices
    idx = np.arange(rpkm_tf[tissue].shape[0])
    train_idx = []
    test_idx = []
    for rep in range(n_rep):
        idx1, idx2 = train_test_split(idx, test_size = test_ratio, shuffle = True)
        train_idx.append(idx1)
        test_idx.append(idx2)
        
    # Train and test each gene.
    res = Parallel(n_jobs = n_jobs)(delayed(train_test_gene)(tissue, gene) 
                              for gene in np.unique(selected_genes[tissue]))
    res = np.vstack(res).T
    r2_all[tissue] = pd.DataFrame(res, index = np.arange(n_rep) + 1, columns = np.unique(selected_genes[tissue]))
# Out:
# 2021-12-12 21:24:25.029141: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:24:25.067160: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:24:25.115477: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:24:25.146372: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:24:25.177896: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:24:25.209414: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:24:25.269367: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:24:25.325175: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:24:25.329080: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:24:25.356219: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:24:25.391297: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:24:25.441386: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:24:25.471850: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:24:25.514182: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:24:25.541438: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:24:32.150986: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:24:32.151028: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:24:32.151044: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:24:32.159063: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:24:32.234843: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:24:32.234874: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:24:32.234891: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:24:32.241396: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:24:32.260009: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:24:32.260041: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:24:32.260058: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:24:32.266061: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:24:32.304161: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:24:32.304204: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:24:32.304227: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:24:32.311344: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:24:32.313161: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:24:32.313204: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:24:32.313227: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:24:32.319897: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:24:32.374097: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:24:32.374131: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:24:32.374150: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:24:32.380229: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:24:32.385030: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:24:32.385071: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:24:32.385088: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:24:32.391428: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:24:32.459058: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:24:32.459102: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:24:32.459119: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:24:32.465524: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:24:32.466340: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:24:32.466369: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:24:32.466386: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:24:32.473336: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:24:32.478003: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:24:32.478036: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:24:32.478053: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:24:32.483477: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:24:32.592512: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:24:32.592548: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:24:32.592568: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:24:32.598839: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:24:32.601847: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:24:32.602122: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:24:32.602159: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:24:32.609297: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:24:32.646511: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:24:32.646543: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:24:32.646565: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:24:32.653025: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:24:32.724057: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:24:32.724105: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:24:32.724128: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:24:32.731024: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:24:32.744118: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:24:32.744165: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:24:32.744187: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:24:32.751029: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:24:40.753923: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:24:40.770898: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:24:40.859413: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:24:40.860191: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:24:41.197390: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:24:41.198172: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:24:41.302635: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:24:41.303405: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:24:41.360745: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:24:41.361502: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:24:41.370524: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:24:41.370966: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:24:41.462074: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:24:41.462870: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:24:41.472161: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:24:41.472647: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:24:41.653320: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:24:41.654085: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:24:42.946556: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:24:42.958907: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:24:42.984060: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:24:42.984890: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:24:43.024290: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:24:43.025205: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:24:43.034586: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:24:43.035518: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:24:44.321324: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:24:44.333947: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:24:44.337279: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:24:44.338183: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# /jet/home/qsong/.local/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py:702: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# 2021-12-12 21:58:01.977887: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:58:08.938287: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:58:08.938319: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:58:08.938338: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:58:08.945913: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:58:18.534179: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:58:18.546900: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:58:21.293314: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:58:25.906179: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:58:28.422458: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:58:28.422498: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:58:28.422514: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:58:28.428908: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:58:33.221700: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:58:33.221751: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:58:33.221770: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:58:33.229454: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:58:36.910529: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:58:37.963824: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:58:37.975950: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:58:42.644175: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:58:42.656922: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:58:43.400887: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:58:43.400920: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:58:43.400935: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:58:43.407485: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:58:47.525137: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 21:58:52.079221: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:58:52.091942: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 21:58:53.866881: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 21:58:53.866919: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 21:58:53.866936: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 21:58:53.873769: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 21:59:02.602295: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 21:59:02.614890: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 22:00:32.041984: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 22:00:38.961716: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 22:00:38.961749: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 22:00:38.961765: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 22:00:38.968435: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 22:00:48.319996: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 22:00:48.331963: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 22:01:04.527483: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 22:01:11.277789: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 22:01:11.277844: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 22:01:11.277862: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 22:01:11.284342: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 22:01:20.462787: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 22:01:20.474893: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 22:14:21.061938: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 22:14:27.913388: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 22:14:27.913614: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 22:14:27.913632: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 22:14:27.920375: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 22:14:36.711670: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 22:14:36.723907: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 22:14:53.518117: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 22:15:00.340775: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 22:15:00.341014: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 22:15:00.341034: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 22:15:00.347175: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 22:15:09.885221: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 22:15:09.897893: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 22:15:34.240350: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 22:15:41.106779: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 22:15:41.106833: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 22:15:41.106849: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 22:15:41.113793: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 22:15:47.058059: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 22:15:50.002022: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 22:15:50.013891: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 22:15:53.715666: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 22:15:53.715701: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 22:15:53.715716: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 22:15:53.722279: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 22:16:02.475256: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 22:16:02.487899: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 22:16:52.577977: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 22:17:00.236134: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 22:17:00.236399: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 22:17:00.236422: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 22:17:00.244452: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 22:17:09.771935: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 22:17:09.783993: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 22:31:02.853891: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 22:31:09.955648: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 22:31:09.955889: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 22:31:09.955909: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 22:31:09.962566: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 22:31:18.845022: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 22:31:18.857921: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 22:31:55.188640: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 22:32:02.609035: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 22:32:02.609084: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 22:32:02.609109: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 22:32:02.616322: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 22:32:12.283057: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 22:32:12.295911: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 22:32:16.026716: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 22:32:22.432010: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 22:32:22.432045: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 22:32:22.432061: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 22:32:22.438232: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 22:32:31.031198: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 22:32:31.044897: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 22:32:48.601368: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 22:32:56.271905: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 22:32:56.271947: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 22:32:56.271970: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 22:32:56.278807: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 22:33:05.223941: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 22:33:05.236948: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 22:48:07.296080: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 22:48:14.448353: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 22:48:14.448387: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 22:48:14.448404: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 22:48:14.455573: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 22:48:23.557115: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 22:48:23.570918: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 22:50:04.243343: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 22:50:10.805479: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 22:50:10.805511: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 22:50:10.805526: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 22:50:10.811878: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 22:50:19.668201: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 22:50:19.680952: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 22:52:25.192292: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 22:52:32.354339: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 22:52:32.354378: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 22:52:32.354396: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 22:52:32.361529: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 22:52:41.662280: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 22:52:41.674925: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 22:53:39.390542: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 22:53:47.397378: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 22:53:47.397423: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 22:53:47.397445: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 22:53:47.405591: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-12 22:53:56.687829: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-12 22:53:56.699908: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-12 23:04:33.861506: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-12 23:04:41.525247: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-12 23:04:41.525293: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-12 23:04:41.525315: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-12 23:04:41.532996: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# ...
# 2021-12-13 00:13:32.632250: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-13 00:13:39.964775: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-13 00:13:39.964828: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-13 00:13:39.964844: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-13 00:13:39.971991: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-13 00:13:48.782676: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-13 00:13:48.794904: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-13 00:13:58.730538: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-13 00:14:05.735168: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-13 00:14:05.735207: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-13 00:14:05.735223: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-13 00:14:05.742296: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-13 00:14:14.609170: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-13 00:14:14.621901: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-13 00:15:14.468618: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-13 00:15:22.628017: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-13 00:15:22.628066: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-13 00:15:22.628083: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-13 00:15:22.635957: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-13 00:15:31.767346: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-13 00:15:31.780008: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-13 00:18:00.865919: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-13 00:18:08.249641: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-13 00:18:08.249677: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-13 00:18:08.249694: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-13 00:18:08.257368: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-13 00:18:17.466796: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-13 00:18:17.479912: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-13 00:26:33.777634: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-13 00:26:41.302908: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-13 00:26:41.302954: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-13 00:26:41.302972: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-13 00:26:41.310302: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-13 00:26:50.729466: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-13 00:26:50.741897: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-13 00:31:39.956430: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-13 00:31:47.563696: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-13 00:31:47.563752: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-13 00:31:47.563770: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-13 00:31:47.571283: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-13 00:31:57.420780: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-13 00:31:57.432897: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-13 00:34:08.536123: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-13 00:34:15.792369: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-13 00:34:15.792408: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-13 00:34:15.792424: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-13 00:34:15.799479: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-13 00:34:16.544188: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-13 00:34:24.007730: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-13 00:34:24.007769: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-13 00:34:24.007785: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-13 00:34:24.014971: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-13 00:34:25.051600: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-13 00:34:25.063941: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-13 00:34:32.941678: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-13 00:34:32.953903: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-13 00:47:48.343846: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-13 00:47:55.708275: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-13 00:47:55.708329: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-13 00:47:55.708349: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-13 00:47:55.715074: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-13 00:48:05.435051: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-13 00:48:05.447903: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-13 00:49:11.086339: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-13 00:49:18.265411: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-13 00:49:18.265451: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-13 00:49:18.265469: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-13 00:49:18.272605: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-13 00:49:27.285737: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-13 00:49:27.297935: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-13 00:51:21.562778: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-13 00:51:29.192896: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-13 00:51:29.193179: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-13 00:51:29.193206: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-13 00:51:29.200917: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-13 00:51:38.651374: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-13 00:51:38.663964: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
# 2021-12-13 00:53:01.766546: I tensorflow/stream_executor/platform/default/dso_loader.cc:54] Successfully opened dynamic library libcudart.so.11.0
# 2021-12-13 00:53:09.054084: W tensorflow/stream_executor/platform/default/dso_loader.cc:65] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/extras/CUPTI/lib64:/usr/local/cuda/compat/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/.singularity.d/libs
# 2021-12-13 00:53:09.054120: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-12-13 00:53:09.054136: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (r427.ib.bridges2.psc.edu): /proc/driver/nvidia/version does not exist
# 2021-12-13 00:53:09.061292: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 128. Tune using inter_op_parallelism_threads for best performance.
# 2021-12-13 00:53:18.163511: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-12-13 00:53:18.175897: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2245805000 Hz
